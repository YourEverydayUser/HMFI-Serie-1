# %% [markdown]
# Aufgabe 1a.)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook 
from mpl_toolkits.mplot3d import Axes3D

def W(v0, alpha):
    return (v0**2 * np.sin(2*alpha))/9.81

[x,y] = np.meshgrid(np.linspace(0, 100), np.linspace(0, np.pi/2))
z = W(x, y)

fig = plt.figure(1)
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(x, y ,z)

plt.title('Gitter')
ax.set_xlabel('Abwurfgeschwindigkeit')
ax.set_ylabel('Abwurfwinkel')
ax.set_zlabel('Wurfdistanz')

plt.show()

#Die maximale Wurfdistanz wird bei einem Abwurfwinkel von 45° erreicht
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure(2)
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x,y,z)

plt.title('Fläche')
ax.set_xlabel('Abwurfgeschwindigkeit')
ax.set_ylabel('Abwurfwinkel')
ax.set_zlabel('Wurfdistanz')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib import cm

fig = plt.figure(3)
cont = plt.contour(x, y, z, cmap=cm.coolwarm)
fig.colorbar(cont, shrink=0.5, aspect=5)

plt.title('Höhenlinien')
plt.xlabel('Abwurfgeschwindigkeit')
plt.ylabel('Abwurfwinkel')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Teilaufgabe b.)
#
# $p = $ Druck in $\frac{N}{m^2}$
#
# $V = $ Volumen in $m^3$
#
# $T = $ absolute Temperatur in Kelvin
#
# $R = $ Gaskonstante in $\frac{J}{molK}$

# %%
R = 8.31

def function_p(V, T):
    return (R * T) / V 

def function_V(p, T):
    return (R*T) / p

def function_T(p, V): 
    return (p * V) / R

[V1,T1] = np.meshgrid(np.linspace(0, 0.2), np.linspace(0, np.e**4))
p_result = function_p(V1, T1)

[p1, T2] = np.meshgrid(np.linspace(np.e**4, np.e**5), np.linspace(0, np.e**4))
V_result = function_V(p1, T2)

[p2, V2] = np.meshgrid(np.linspace(np.e**4, np.e**6), np.linspace(0, 10))
T_result = function_T(p2, V2)

fig = plt.figure(4)
fig.set_size_inches(15, 8)
ax = fig.add_subplot(221, projection='3d')
ax.plot_wireframe(V1, T1 ,p_result)

ax2 = fig.add_subplot(222, projection='3d')
ax2.plot_wireframe(p1, T2, V_result)

ax3 = fig.add_subplot(223, projection='3d')
ax3.plot_wireframe(p2, V2, T_result)

plt.title('Gitter')
ax.set_xlabel('Volumen in $m^3$')
ax.set_ylabel('Absolute Temperatur in Kelvin')
ax.set_zlabel('Druck in $N / m^2$')

ax2.set_xlabel('Druck in $N / m^2$')
ax2.set_ylabel('Absolute Temperatur in Kelvin')
ax2.set_zlabel('Volumen in $m^3$')

ax3.set_xlabel('Druck in $N / m^2$')
ax3.set_ylabel('Volumen in $m^3$')
ax3.set_zlabel('Absolute Temperatur in Kelvin')

plt.show()
# Out:
# C:\Users\Fabian\AppData\Local\Temp\ipykernel_5000\2891192386.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   return (R * T) / V
# C:\Users\Fabian\AppData\Local\Temp\ipykernel_5000\2891192386.py:4: RuntimeWarning: invalid value encountered in true_divide
#   return (R * T) / V
# <img src="data:image/png;base64,..." width="1500">

# %%
fig = plt.figure(5)
fig.set_size_inches(15, 8)

ax = fig.add_subplot(221, projection='3d')
ax.plot_surface(V1, T1 ,p_result)

ax2 = fig.add_subplot(222, projection='3d')
ax2.plot_surface(p1, T2, V_result)

ax3 = fig.add_subplot(223, projection='3d')
ax3.plot_surface(p2, V2, T_result)

plt.title('Fläche')
ax.set_xlabel('Volumen in $m^3$')
ax.set_ylabel('Absolute Temperatur in Kelvin')
ax.set_zlabel('Druck in $N / m^2$')

ax2.set_xlabel('Druck in $N / m^2$')
ax2.set_ylabel('Absolute Temperatur in Kelvin')
ax2.set_zlabel('Volumen in $m^3$')

ax3.set_xlabel('Druck in $N / m^2$')
ax3.set_ylabel('Volumen in $m^3$')
ax3.set_zlabel('Absolute Temperatur in Kelvin')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
fig = plt.figure(5)
cont = plt.contour(V1, T1, p_result, cmap=cm.coolwarm)
fig.colorbar(cont, shrink=0.5, aspect=5)
plt.title('Höhenlinien Druck')
plt.xlabel('Volumen')
plt.ylabel('Temperatur')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Temperatur')

# %%
fig = plt.figure(6)
cont = plt.contour(p1, T2, V_result, cmap=cm.coolwarm)
fig.colorbar(cont, shrink=0.5, aspect=5)
plt.title('Höhenlinien Volumen')
plt.xlabel('Druck')
plt.ylabel('Temperatur')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Temperatur')

# %%
fig = plt.figure(7)
cont = plt.contour(p2, V2, T_result, cmap=cm.coolwarm)
fig.colorbar(cont, shrink=0.5, aspect=5)
plt.title('Höhenlinien Temperatur')
plt.xlabel('Volumen')
plt.ylabel('Temperatur')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Höhenlinien Temperatur')

# %% [markdown]
# Aufgabe 2b.)

# %%
def w(x, t):
    return np.sin(x+t)

def v(x, t):
    return np.sin(x+t) + np.cos(2*x+2*t)

[x,t] = np.meshgrid(np.linspace(0, 8), np.linspace(0, 8))
w_result = w(x, t)

[x2,t2] = np.meshgrid(np.linspace(0, 8), np.linspace(0, 8))
v_result = v(x2, t2)

fig = plt.figure(8)
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(x, t, w_result)

ax.set_xlabel('x')
ax.set_ylabel('t')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure(9)
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(x2, t2, v_result)

plt.title('Gitter')
ax.set_xlabel('x')
ax.set_ylabel('t')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0.5, 't')
